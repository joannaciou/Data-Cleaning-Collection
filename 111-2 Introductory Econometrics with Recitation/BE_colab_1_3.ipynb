# %%
# -*- coding: utf8 -*-
import pandas as pd
from google.colab import files #匯入套件
upload = files.upload() #開啟上傳介面並載入
upload = files.upload()
# Out:
#      <input type="file" id="files-f69a3d53-d7cc-4054-b2a5-48a43b8d8e1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f69a3d53-d7cc-4054-b2a5-48a43b8d8e1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# path: "C:\Users\88698\Desktop\BE_hw1"

df_2 = pd.read_excel("collegename_clean.xlsx")
df_3 = pd.read_excel("student_clean.xlsx")

df_2 = df_2.astype({'college': 'string', 'dcode': 'string', 'scode': 'string'})
df_3 = df_3.astype({'dcode': 'string', 'test id': 'string'})

# %%
df_2.head()
# Out:
#   college department dcode scode  n1  n2
# 0  國立臺灣大學      中國文學系     1     1  41  41
# 1  國立臺灣大學     外國語文學系     2     1  73  73
# 2  國立臺灣大學       歷史學系     3     1  36  36
# 3  國立臺灣大學        哲學系     4     1  36  36
# 4  國立臺灣大學       人類學系     5     1  32  32

# %%
df_3.tail()
# Out:
#       dcode name   test id
# 88931  3173  張仲名  22127607
# 88932  3173  黃伊萍  22049127
# 88933  3173  李蕙庭  22065419
# 88934  3173  呂俊輝  22043720
# 88935  3173  簡得洲  22056920

# %%
df_3.insert(0, "college", "")
df_3.insert(1, "department", "")
df_3.insert(5, "scode", "")
df_3.insert(6, "n1", "")
df_3.insert(7, "n2", "")

# %%
for i in range(len(df_3['dcode'])):
    
    for j in range(len(df_2['dcode'])):
        if df_2['dcode'][j] == df_3['dcode'][i]:
            df_3["college"][i] = df_2['college'][j]
            df_3["department"][i] = df_2['department'][j]
            df_3["scode"][i] = df_2['scode'][j]
            df_3["n1"][i] = df_2['n1'][j]
            df_3["n2"][i] = df_2['n2'][j]
        else:
            pass

df_3.head(50)
# Out:
# <ipython-input-36-91db4a4a6e67>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["college"][i] = df_2['college'][j]
# <ipython-input-36-91db4a4a6e67>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["department"][i] = df_2['department'][j]
# <ipython-input-36-91db4a4a6e67>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3["scode"][i] = df_2['scode'][j]
# ...

# %%
df_3.tail(55)
# Out:
#       college department dcode name   test id scode  n1  n2
# 88881  國立聯合大學     資訊工程學系  3172  周秉宜  21091437   151  50  50
# 88882  國立聯合大學     資訊工程學系  3172  黃琮期  21096227   151  50  50
# 88883  國立聯合大學     資訊工程學系  3172  李建政  21076512   151  50  50
# 88884  國立聯合大學     資訊工程學系  3172  卓　岱  21058938   151  50  50
# 88885  國立聯合大學     資訊工程學系  3172  溫展儀  21087313   151  50  50
# 88886  國立聯合大學  台灣語文與傳播學系  3173  石耀宇  22052407   151  50  50
# 88887  國立聯合大學  台灣語文與傳播學系  3173  呂汶宜  22085705   151  50  50
# 88888  國立聯合大學  台灣語文與傳播學系  3173  楊書綸  22001122   151  50  50
# 88889  國立聯合大學  台灣語文與傳播學系  3173  林靖書  22112925   151  50  50
# 88890  國立聯合大學  台灣語文與傳播學系  3173  彭凱筠  22071816   151  50  50
# 88891  國立聯合大學  台灣語文與傳播學系  3173  張國揚  22083634   151  50  50
# 88892  國立聯合大學  台灣語文與傳播學系  3173  洪佳芸  22110442   151  50  50
# 88893  國立聯合大學  台灣語文與傳播學系  3173  楊毓琳  22089735   151  50  50
# 88894  國立聯合大學  台灣語文與傳播學系  3173  陳世昌  22096723   151  50  50
# 88895  國立聯合大學  台灣語文與傳播學系  3173  謝毓濱  22077726   151  50  50
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_3.to_excel('/content/drive/MyDrive/BE_hw1/done.xlsx')
